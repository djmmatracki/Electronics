# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Charakterystyka amplitudowo-częstotliwościowa filtru pasmowoprzepustowego II rzędu

# %%
f = np.array([1, 1.3, 1.7, 2.1, 2.8, 3.6, 4.6, 6, 7.7, 10, 13, 17, 21, 28, 36, 46, 60, 77, 100])
Vpp_wej = np.array([1.02] * 19)
Vpp_wyj = np.array([0.180, 0.220, 0.280, 0.320, 0.400, 0.460, 0.520, 0.580, 0.600, 0.640, 0.620, 0.580, 0.540, 0.460, 0.400, 0.320, 0.280, 0.240, 0.200])


plt.scatter(f, Vpp_wyj)
plt.show()

plt.scatter(f, Vpp_wyj/Vpp_wej)
plt.show()

# %%
# okres = np.array([480, 400, 300, 248, 184, 136, 104, 88, 64, 52, 39.2, 29.6, 24, 17.6, 14, 10.8, 8.4, 6.40, 5]) * 10**(-6)
okres = np.array([780, 608, 480, 392, 304, 240, 194, 154, 126, 98, 80, 64, 43.2, 31.6, 23.6, 18.8, 14, 10.2, 8]) * 10**(-6)
# okres = np.array([]) * 10**(-6)
